# %%
import requests
import random
print("hello")
# Out:
# hello

# %%
BASE_URL = "https://fakestoreapi.com/products"

# %%
def fetch_products():
    try:
        response = requests.get(BASE_URL, timeout=10)

        if response.status_code != 200:
            return {
                "success": False,
                "error": f"API failed with status {response.status_code}"
            }

        data = response.json()

        products = []

    
        for item in random.sample(data, 8):
            products.append({
                "title": item.get("title"),
                "price": item.get("price"),
                "category": item.get("category"),
                "rating": item.get("rating", {}).get("rate"),
                "image": item.get("image")
            })

        return {
            "success": True,
            "products": products
        }

    except requests.exceptions.RequestException as e:
        return {
            "success": False,
            "error": str(e)
        }


if __name__ == "__main__":
    result = fetch_products()
    print(result)
# Out:
# {'success': True, 'products': [{'title': "MBJ Women's Solid Short Sleeve Boat Neck V ", 'price': 9.85, 'category': "women's clothing", 'rating': 4.7, 'image': 'https://fakestoreapi.com/img/71z3kpMAYsL._AC_UY879_t.png'}, {'title': 'Mens Casual Slim Fit', 'price': 15.99, 'category': "men's clothing", 'rating': 2.1, 'image': 'https://fakestoreapi.com/img/71YXzeOuslL._AC_UY879_t.png'}, {'title': 'SanDisk SSD PLUS 1TB Internal SSD - SATA III 6 Gb/s', 'price': 109, 'category': 'electronics', 'rating': 2.9, 'image': 'https://fakestoreapi.com/img/61U7T1koQqL._AC_SX679_t.png'}, {'title': "Lock and Love Women's Removable Hooded Faux Leather Moto Biker Jacket", 'price': 29.95, 'category': "women's clothing", 'rating': 2.9, 'image': 'https://fakestoreapi.com/img/81XH0e8fefL._AC_UY879_t.png'}, {'title': 'Mens Cotton Jacket', 'price': 55.99, 'category': "men's clothing", 'rating': 4.7, 'image': 'https://fakestoreapi.com/img/71li-ujtlUL._AC_UX679_t.png'}, {'title': 'Fjallraven - Foldsack No. 1 Backpack, Fits 15 Laptops', 'price': 109.95, 'category': "men's clothing", 'rating': 3.9, 'image': 'https://fakestoreapi.com/img/81fPKd-2AYL._AC_SL1500_t.png'}, {'title': 'Silicon Power 256GB SSD 3D NAND A55 SLC Cache Performance Boost SATA III 2.5', 'price': 109, 'category': 'electronics', 'rating': 4.8, 'image': 'https://fakestoreapi.com/img/71kWymZ+c+L._AC_SX679_t.png'}, {'title': 'Samsung 49-Inch CHG90 144Hz Curved Gaming Monitor (LC49HG90DMNXZA) – Super Ultrawide Screen QLED ', 'price': 999.99, 'category': 'electronics', 'rating': 2.2, 'image': 'https://fakestoreapi.com/img/81Zt42ioCgL._AC_SX679_t.png'}]}
