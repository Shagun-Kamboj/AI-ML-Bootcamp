# %%
from IPython.display import HTML, display

cover_page = """
<div style="
    width:100%;
    height:320px;
    background:linear-gradient(135deg,#5B6EE1,#7E57C2,#F06292);
    border:5px solid white;
    border-radius:20px;
    box-shadow:0 10px 25px rgba(0,0,0,0.35);
    font-family:Arial, sans-serif;
    position:relative;
    overflow:hidden;
">

    <!-- Top Left -->
    <div style="
        position:absolute;
        top:20px;
        left:35px;
        font-size:20px;
        font-weight:bold;
        color:#FFE66D;
        letter-spacing:3px;">
        🚀 PYTHON PROJECT 🚀
    </div>

    <!-- Main Title -->
    <div style="
        position:absolute;
        top:70px;
        left:50%;
        transform:translateX(-50%);
        text-align:center;">

        <div style="
            font-size:65px;
            font-weight:bold;
            color:white;
            text-shadow:3px 3px 10px rgba(0,0,0,0.5);">
            🌐 Web Scraping 🌐
        </div>

        <div style="
            width:240px;
            height:5px;
            background:white;
            margin:12px auto;
            border-radius:10px;">
        </div>

    </div>

    <!-- Bottom Left -->
    <div style="
        position:absolute;
        bottom:35px;
        left:35px;
        font-size:30px;
        font-weight:bold;
        color:#FFD700;">
        ✨ Shagun Kamboj ✨
    </div>

    <!-- Bottom Right -->
    <div style="
        position:absolute;
        bottom:35px;
        right:35px;
        font-size:18px;
        color:white;
        text-align:right;
        line-height:1.8;">
        📚 Data Collection<br>
        🐍 Python<br>
        🌍 BeautifulSoup
    </div>

</div>
"""

display(HTML(cover_page))
# Out:
# <div style="
#     width:100%;
#     height:320px;
#     background:linear-gradient(135deg,#5B6EE1,#7E57C2,#F06292);
#     border:5px solid white;
#     border-radius:20px;
#     box-shadow:0 10px 25px rgba(0,0,0,0.35);
#     font-family:Arial, sans-serif;
#     position:relative;
#     overflow:hidden;
# ">
#
#     <!-- Top Left -->
#     <div style="
#         position:absolute;
#         top:20px;
#         left:35px;
#         font-size:20px;
#         font-weight:bold;
#         color:#FFE66D;
#         letter-spacing:3px;">
#         🚀 PYTHON PROJECT 🚀
#     </div>
#
#     <!-- Main Title -->
#     <div style="
#         position:absolute;
#         top:70px;
#         left:50%;
#         transform:translateX(-50%);
#         text-align:center;">
#
#         <div style="
#             font-size:65px;
#             font-weight:bold;
#             color:white;
#             text-shadow:3px 3px 10px rgba(0,0,0,0.5);">
#             🌐 Web Scraping 🌐
#         </div>
#
# ...

# %%
from IPython.display import HTML, display

display(HTML("""
<div style="
    background:linear-gradient(135deg,#f4f7f6,#eff5f9);
    border:3px solid #b0cddb;
    border-radius:18px;
    padding:20px;
    margin:20px 0;
    box-shadow:0 8px 18px rgba(0,0,0,0.15);
">

<h1 style="
    color:#1e3a5f;
    font-family:Trebuchet MS, sans-serif;
    font-size:42px;
    margin:0;
    display: flex;
    align-items: centre
    gap: 15px;">
🏫 Website Name : 


<span style="
    font-size:30px;
    font-weight:bold;
    color:#4a3b68;
    margin-top:10px;
    font-family:Georgia;">
      🌐 Collegedunia.com
  </span>
</h1>

<hr style="
    border:none;
    height:4px;
    background:linear-gradient(to right,#ff69b4,#7b68ee,#00bcd4);
    border-radius:10px;">

<div style="
    margin-top:20px;
    padding:18px;
    background:linear-gradient(90deg,#fff8e1,#e3f2fd);
    border-left:8px solid #3f51b5;
    border-radius:15px;
    box-shadow:0 4px 10px rgba(0,0,0,0.1);
">

<h2 style="
    color:#1a237e;
    font-size:30px;
    font-family:Verdana,sans-serif;
    margin:0;">
📡 Step 1 : Sending HTTP Request 🌐
</h2>

<p style="
    font-size:18px;
    color:#555;
    margin-top:10px;
    font-family:Calibri;">
📥 Connect to <b>Collegedunia.com</b> using the <b>Requests</b> library and retrieve the webpage for scraping.
</p>

</div>

</div>
"""))
# Out:
# <div style="
#     background:linear-gradient(135deg,#f4f7f6,#eff5f9);
#     border:3px solid #b0cddb;
#     border-radius:18px;
#     padding:20px;
#     margin:20px 0;
#     box-shadow:0 8px 18px rgba(0,0,0,0.15);
# ">
#
# <h1 style="
#     color:#1e3a5f;
#     font-family:Trebuchet MS, sans-serif;
#     font-size:42px;
#     margin:0;
#     display: flex;
#     align-items: centre
#     gap: 15px;">
# 🏫 Website Name :
#
#
# <span style="
#     font-size:30px;
#     font-weight:bold;
#     color:#4a3b68;
#     margin-top:10px;
#     font-family:Georgia;">
#       🌐 Collegedunia.com
#   </span>
# </h1>
#
# <hr style="
#     border:none;
#     height:4px;
#     background:linear-gradient(to right,#ff69b4,#7b68ee,#00bcd4);
#     border-radius:10px;">
#
# <div style="
#     margin-top:20px;
#     padding:18px;
#     background:linear-gradient(90deg,#fff8e1,#e3f2fd);
#     border-left:8px solid #3f51b5;
#     border-radius:15px;
#     box-shadow:0 4px 10px rgba(0,0,0,0.1);
# ">
#
# ...

# %%
import requests

# %%
url = "https://collegedunia.com"
headers={ "User-Agent": "Mozilla/5.0(Windows NT 10.0; Win64 ; x64) appleWebKit/537.36 (KHTML ,Like Gecko Chrome/91.0.4472.124 Safari/537.36"}
response = requests.get(url , headers = headers)

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# <div style="border: 2px solid #b0cddb; border-radius: 20px; padding: 20px; background-color: #f4f7f6; font-family: 'Segoe UI', sans-serif;">
#     <div style="background-color: #eef4f8; border-radius: 15px; padding: 15px; border-left: 5px solid #4a90e2;">
#         <h2 style="color: #6a1b9a; margin: 0 0 10px 0; display: flex; align-items: center; font-size: 22px;">
#             📄 Step 2 : Extract HTML Content &nbsp;🌐
#         </h2>
#         <p style="color: #4a5568; margin: 0; font-size: 16px;">
#             ⚙️ Extract the raw text data/HTML source code from the website's response.
#         </p>
#     </div>
# </div>

# %%
html_code = response.text
#html_code

# %% [markdown]
# <div style="border: 2px solid #b2dfdb; border-radius: 20px; padding: 20px; background-color: #f4fbf9; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; box-shadow: 0 4px 15px rgba(178, 223, 219, 0.2);">
#     <div style="background-color: #e0f2f1; border-radius: 15px; padding: 18px; border-left: 6px solid #009688;">
#         <h2 style="color: #004d40; margin: 0 0 10px 0; display: flex; align-items: center; font-size: 24px; font-weight: 700; letter-spacing: 0.5px;">
#             🔍 Step 3 : Parsing the HTML &nbsp;🌐
#         </h2>
#         <p style="color: #2d3748; margin: 0; font-size: 16px; font-weight: 500; line-height: 1.5;">
#             🥣 Parse the raw HTML code using <b style="color: #00796b; background-color: #b2dfdb; padding: 2px 6px; border-radius: 4px;">BeautifulSoup</b> to structure it into a readable tree format.
#         </p>
#     </div>
# </div>

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
soup = BeautifulSoup(html_code, "html.parser")
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1,minimum-scale=1.0, maximum-scale=2.0, user-scalable=yes, shrink-to-fit=no,viewport-fit=cover" name="viewport"/>
#   <link as="image" class="jsx-4281398864 jsx-637017680" fetchpriority="high" href="https://image-static.collegedunia.com/public/images/cd_logo_dark_new.png" rel="preload"/>
#   <link as="image" class="jsx-4281398864 jsx-637017680" fetchpriority="high" href="https://image-static.collegedunia.com/public/images/cd_logo_white_new.png" rel="preload"/>
#   <link as="image" class="jsx-4281398864 jsx-637017680" fetchpriority="high" href="https://image-static.collegedunia.com/public/asset/sprite/common-header-sprite.svg" rel="preload"/>
#   <title>
#    Collegedunia: Top Colleges, Universities &amp; Institutes in India | Admission, Fees, Rankings of Top Management, Engineering, Medical Colleges
#   </title>
# ...

# %%
# rows = soup.find_all("tbody")
table = soup.find("table")
rows = table.find_all("tr")

# %%
rows
# Out:
# [<tr class="jsx-831255015"><th class="jsx-831255015">Rank</th><th class="jsx-831255015">College</th><th class="jsx-831255015">Ranking</th><th class="jsx-831255015">Cutoff</th><th class="jsx-831255015 text-nowrap">Application Deadline</th><th class="jsx-831255015">Total Fees</th></tr>,
# ...

# %%
information = []

for row in rows:
    cols = row.find_all('td')
    if len(cols) >= 3: 
        Rank = cols[0].get_text(strip=True) 
        college_name = cols[1].get_text(strip=True)
        ranking = cols[2].get_text(strip=True)
        
        information.append({
            "Rank": Rank,
            "College_Name": college_name,
            "Ranking": ranking
        })

# %%
df = pd.DataFrame(information)

# %%
df
# Out:
#   Rank                                       College_Name  \
# 0   #1  IIT Delhi - Indian Institute of Technology [II...
# 1   #2  IIMA - Indian Institute of ManagementAhmedabad...
# 2   #3  All India Institute of Medical Sciences - [AII...
# 3   #4  National Law School of India University - [NLS...
# 4   #5  Vardhman Mahavir Medical College - [VMMC]New D...
# 5   #6  IIT Bombay - Indian Institute of Technology - ...
# 6   #7  IIMC - Indian Institute of ManagementKolkata,W...
# 7   #8  Shri Ram College of Commerce - [SRCC]New Delhi...
# 8   #9  Institute of Hotel Management, Catering and Nu...
# 9  #10  School of Planning and Architecture - [SPA]New...
#
#                         Ranking
# 0     #3out of 50 in India 2025
# 1     #2out of 50 in India 2019
# 2    #8out of 200 in India 2025
# 3                             -
# 4                             -
# 5     #2out of 50 in India 2025
# 6   #99out of 200 in India 2023
# 7   #18out of 300 in India 2025
# ...
