# %%
import requests

# %%
BASE_URL = "https://api.thecatapi.com/v1/images/search?limit=10"

# %%
def fetch_cats():

    try:

        response = requests.get(BASE_URL, timeout=10)

        if response.status_code != 200:
            return {
                "success": False,
                "error": f"API failed with status {response.status_code}"
            }

        data = response.json()

        cats = []

        for item in data:

            cats.append({
                "id": item.get("id"),
                "image": item.get("url")
            })

        return {
            "success": True,
            "cats": cats
        }

    except requests.exceptions.RequestException as e:

        return {
            "success": False,
            "error": str(e)
        }


if __name__ == "__main__":

    result = fetch_cats()

    print(result)
# Out:
# {'success': True, 'cats': [{'id': '38t', 'image': 'https://cdn2.thecatapi.com/images/38t.jpg'}, {'id': '49g', 'image': 'https://cdn2.thecatapi.com/images/49g.gif'}, {'id': '4q7', 'image': 'https://cdn2.thecatapi.com/images/4q7.gif'}, {'id': '5rp', 'image': 'https://cdn2.thecatapi.com/images/5rp.jpg'}, {'id': '7ka', 'image': 'https://cdn2.thecatapi.com/images/7ka.jpg'}, {'id': '8mh', 'image': 'https://cdn2.thecatapi.com/images/8mh.jpg'}, {'id': 'ab1', 'image': 'https://cdn2.thecatapi.com/images/ab1.jpg'}, {'id': 'chp', 'image': 'https://cdn2.thecatapi.com/images/chp.jpg'}, {'id': 'MTUxNzkyOA', 'image': 'https://cdn2.thecatapi.com/images/MTUxNzkyOA.jpg'}, {'id': 'jUY0Dt5iB', 'image': 'https://cdn2.thecatapi.com/images/jUY0Dt5iB.jpg'}]}
