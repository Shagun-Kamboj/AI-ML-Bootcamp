# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
np.random.seed(42)
n=10000
df = pd.DataFrame({
    "Age" :np.random.randint(17,26,n),
    "Gender" : np.random.choice(["Male","Female"],n),
    "Attendance" : np.random.randint(40,101,n),
    "CGPA" : np.round(np.random.uniform(4.5,10,n),2),
    "Backlogs" : np.random.randint(0,8,n),
    "FamilyIncome": np.random.randint(15000,2000000,n),
   # "StudyHours" : np.round(np.random.uniform(0.5,8,n),
    "StudyHours": np.round(np.random.uniform(0.5, 8, n), 2),
    "Schlorship": np.random.choice([0,1],n,p=[0.7,0.3]),
    "InternetAcess" : np.random.choice([0,1],n,p=[0.15,0.85]),
    "Hostel" : np.random.choice([0,1],n),
    "MentalStress": np.random.randint(1,11,n),
    "PartTimejob" : np.random.choice([0,1],n,p=[0.75,0.25])
 })

# %%
risk = (
    (df["Attendance"] <65).astype(int) +
    (df["CGPA"] <6.0).astype(int) +
    (df["Backlogs"] >=3).astype(int) +
    (df["MentalStress"]>=8).astype(int) +
    (df["StudyHours"] <2).astype(int) 
)

df["Dropout"] = np.where(risk>=3,1,0)

# %%
df
# Out:
#       Age  Gender  Attendance  CGPA  Backlogs  FamilyIncome  StudyHours  \
# 0      23  Female          70  5.71         3        512769        7.73
# 1      20  Female          45  6.17         6        268202        4.38
# 2      24    Male          53  5.21         7        642807        4.79
# 3      21  Female          97  5.87         0       1505601        5.50
# 4      23    Male          62  9.02         2        511632        6.48
# ...   ...     ...         ...   ...       ...           ...         ...
# 9995   17  Female          70  4.77         6       1161551        5.48
# 9996   23    Male          48  7.05         5       1139568        3.07
# 9997   22    Male          61  9.10         0       1184896        5.22
# 9998   25  Female          50  5.49         5        367406        2.38
# 9999   23  Female          56  5.30         5        579012        2.69
#
#       Schlorship  InternetAcess  Hostel  MentalStress  PartTimejob  Dropout
# 0              0              1       0             2            0        0
# 1              1              1       0             3            0        0
# 2              1              1       1             1            1        1
# 3              0              1       0             8            1        0
# 4              0              1       0             6            0        0
# ...          ...            ...     ...           ...          ...      ...
# 9995           0              1       0            10            0        1
# 9996           0              1       1             5            0        0
# 9997           0              0       0             5            0        0
# 9998           1              1       1             6            0        1
# 9999           1              1       0             8            0        1
#
# [10000 rows x 13 columns]

# %%
X = df.drop("Dropout",axis=1)
y = df["Dropout"]

# %%
X = pd.get_dummies(X,drop_first=True)

# %%
X
# Out:
#       Age  Attendance  CGPA  Backlogs  FamilyIncome  StudyHours  Schlorship  \
# 0      23          70  5.71         3        512769        7.73           0
# 1      20          45  6.17         6        268202        4.38           1
# 2      24          53  5.21         7        642807        4.79           1
# 3      21          97  5.87         0       1505601        5.50           0
# 4      23          62  9.02         2        511632        6.48           0
# ...   ...         ...   ...       ...           ...         ...         ...
# 9995   17          70  4.77         6       1161551        5.48           0
# 9996   23          48  7.05         5       1139568        3.07           0
# 9997   22          61  9.10         0       1184896        5.22           0
# 9998   25          50  5.49         5        367406        2.38           1
# 9999   23          56  5.30         5        579012        2.69           1
#
#       InternetAcess  Hostel  MentalStress  PartTimejob  Gender_Male
# 0                 1       0             2            0        False
# 1                 1       0             3            0        False
# 2                 1       1             1            1         True
# 3                 1       0             8            1        False
# 4                 1       0             6            0         True
# ...             ...     ...           ...          ...          ...
# 9995              1       0            10            0        False
# 9996              1       1             5            0         True
# 9997              0       0             5            0         True
# 9998              1       1             6            0        False
# 9999              1       0             8            0        False
#
# [10000 rows x 12 columns]

# %%
X_train,X_test,y_train,y_test = train_test_split
6 MB/s eta 0:00:14
#    ---------------------------- ----------- 49.0/69.5 MB 1.6 MB/s eta 0:00:14
#    ---------------------------- ----------- 49.3/69.5 MB 1.6 MB/s eta 0:00:13
#    ---------------------------- ----------- 49.8/69.5 MB 1.6 MB/s eta 0:00:13
#    ---------------------------- ----------- 50.1/69.5 MB 1.6 MB/s eta 0:00:13
#    ---------------------------- ----------- 50.1/69.5 MB 1.6 MB/s eta 0:00:13
#    ----------------------------- ---------- 50.6/69.5 MB 1.6 MB/s eta 0:00:12
#    ----------------------------- ---------- 51.1/69.5 MB 1.6 MB/s eta 0:00:12
#    ----------------------------- ---------- 51.6/69.5 MB 1.6 MB/s eta 0:00:12
#    ------------------------------ --------- 52.2/69.5 MB 1.6 MB/s eta 0:00:11
#    ------------------------------ --------- 52.7/69.5 MB 1.6 MB/s eta 0:00:11
#    ------------------------------ --------- 53.2/69.5 MB 1.6 MB/s eta 0:00:10
#    ------------------------------ --------- 53.7/69.5 MB 1.7 MB/s eta 0:00:10
#    ------------------------------- -------- 54.3/69.5 MB 1.7 MB/s eta 0:00:10
#    ------------------------------- -------- 55.1/69.5 MB 1.7 MB/s eta 0:00:09
#    ------------------------------- -------- 55.3/69.5 MB 1.7 MB/s eta 0:00:09
#    -------------------------------- ------- 55.8/69.5 MB 1.7 MB/s eta 0:00:09
#    -------------------------------- ------- 56.4/69.5 MB 1.7 MB/s eta 0:00:08
#    -------------------------------- ------- 56.9/69.5 MB 1.7 MB/s eta 0:00:08
#    -------------------------------- ------- 56.9/69.5 MB 1.7 MB/s eta 0:00:08
#    -------------------------------- ------- 57.1/69.5 MB 1.7 MB/s eta 0:00:08
#    -------------------------------- ------- 57.1/69.5 MB 1.7 MB/s eta 0:00:08
#    --------------------------------- ------ 57.4/69.5 MB 1.6 MB/s eta 0:00:08
#    --------------------------------- ------ 57.4/69.5 MB 1.6 MB/s eta 0:00:08
#    --------------------------------- ------ 57.4/69.5 MB 1.6 MB/s eta 0:00:08
#    --------------------------------- ------ 57.7/69.5 MB 1.6 MB/s eta 0:00:08
#    --------------------------------- ------ 57.7/69.5 MB 1.6 MB/s eta 0:00:08
#    --------------------------------- ------ 57.9/69.5 MB 1.6 MB/s eta 0:00:08
#    --------------------------------- ------ 57.9/69.5 MB 1.6 MB/s eta 0:00:08
#    --------------------------------- ------ 58.2/69.5 MB 1.6 MB/s eta 0:00:08
#    --------------------------------- ------ 58.5/69.5 MB 1.6 MB/s eta 0:00:07
#    --------------------------------- ------ 58.5/69.5 MB 1.6 MB/s eta 0:00:07
#    --------------------------------- ------ 58.7/69.5 MB 1.6 MB/s eta 0:00:07
#    --------------------------------- ------ 59.0/69.5 MB 1.6 MB/s eta 0:00:07
#    ---------------------------------- ----- 59.2/69.5 MB 1.6 MB/s eta 0:00:07
#    ---------------------------------- ----- 59.5/69.5 MB 1.6 MB/s eta 0:00:07
#    ---------------------------------- ----- 60.0/69.5 MB 1.6 MB/s eta 0:00:07
#    ---------------------------------- ----- 60.0/69.5 MB 1.6 MB/s eta 0:00:07
#    ---------------------------------- ----- 60.3/69.5 MB 1.5 MB/s eta 0:00:07
#    ---------------------------------- ----- 60.6/69.5 MB 1.5 MB/s eta 0:00:06
#    ----------------------------------- ---- 61.1/69.5 MB 1.5 MB/s eta 0:00:06
#    ----------------------------------- ---- 61.3/69.5 MB 1.5 MB/s eta 0:00:06
#    ----------------------------------- ---- 61.3/69.5 MB 1.5 MB/s eta 0:00:06
#    ----------------------------------- ---- 61.6/69.5 MB 1.5 MB/s eta 0:00:06
#    ----------------------------------- ---- 61.6/69.5 MB 1.5 MB/s eta 0:00:06
#    ----------------------------------- ---- 61.9/69.5 MB 1.4 MB/s eta 0:00:06
#    ----------------------------------- ---- 62.1/69.5 MB 1.4 MB/s eta 0:00:06
#    ----------------------------------- ---- 62.4/69.5 MB 1.4 MB/s eta 0:00:06
#    ----------------------------------- ---- 62.4/69.5 MB 1.4 MB/s eta 0:00:06
#    ----------------------------------- ---- 62.4/69.5 MB 1.4 MB/s eta 0:00:06
#    ------------------------------------ --- 62.7/69.5 MB 1.4 MB/s eta 0:00:05
#    ------------------------------------ --- 62.9/69.5 MB 1.4 MB/s eta 0:00:05
#    ------------------------------------ --- 62.9/69.5 MB 1.4 MB/s eta 0:00:05
#    ------------------------------------ --- 63.2/69.5 MB 1.4 MB/s eta 0:00:05
#    ------------------------------------ --- 63.4/69.5 MB 1.4 MB/s eta 0:00:05
#    ------------------------------------ --- 63.7/69.5 MB 1.4 MB/s eta 0:00:05
#    ------------------------------------ --- 64.2/69.5 MB 1.4 MB/s eta 0:00:04
#    ------------------------------------- -- 64.5/69.5 MB 1.4 MB/s eta 0:00:04
#    ------------------------------------- -- 64.5/69.5 MB 1.4 MB/s eta 0:00:04
#    ------------------------------------- -- 64.7/69.5 MB 1.4 MB/s eta 0:00:04
#    ------------------------------------- -- 65.3/69.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------- -- 65.3/69.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------- -- 65.3/69.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------- -- 65.3/69.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------- -- 65.5/69.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------- -- 65.8/69.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------- -- 65.8/69.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------- -- 65.8/69.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------------- -- 65.8/69.5 MB 1.4 MB/s eta 0:00:03
#    -------------------------------------- - 66.1/69.5 MB 1.4 MB/s eta 0:00:03
#    -------------------------------------- - 66.1/69.5 MB 1.4 MB/s eta 0:00:03
#    -------------------------------------- - 66.3/69.5 MB 1.4 MB/s eta 0:00:03
#    -------------------------------------- - 66.3/69.5 MB 1.4 MB/s eta 0:00:03
#    -------------------------------------- - 66.3/69.5 MB 1.4 MB/s eta 0:00:03
#    -------------------------------------- - 66.6/69.5 MB 1.4 MB/s eta 0:00:03
#    -------------------------------------- - 66.8/69.5 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 67.1/69.5 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 67.4/69.5 MB 1.4 MB/s eta 0:00:02
#    ---------------------------------------  67.9/69.5 MB 1.4 MB/s eta 0:00:02
#    ---------------------------------------  67.9/69.5 MB 1.4 MB/s eta 0:00:02
#    ---------------------------------------  68.2/69.5 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------------  68.4/69.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  68.4/69.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  68.9/69.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  68.9/69.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  69.2/69.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  69.5/69.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  69.5/69.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  69.5/69.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 69.5/69.5 MB 1.3 MB/s  0:00:49
# Installing collected packages: xgboost
# Successfully installed xgboost-3.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "KNN":KNeighborsClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "SVM": SVC(),
    "XGBoost": XGBClassifier(),
    "Naive Bayes": GaussianNB()  
}

# %%
result = []
for name, model in models.items():
    model.fit(X_train, y_train)
    pred = model.predict(X_test)

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score
)

results = []

for name, model in models.items():

    # Train
    model.fit(X_train, y_train)

    # Predict class labels
    y_pred = model.predict(X_test)

    # Predict probabilities
    if hasattr(model, "predict_proba"):
        y_prob = model.predict_proba(X_test)[:, 1]
    else:
        # SVM without probability=True
        y_prob = y_pred

    results.append({
        "Model": name,
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1 Score": f1_score(y_test, y_pred),
        "ROC AUC": roc_auc_score(y_test, y_prob)
    })
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
result_df = pd.DataFrame(results)
result_df = result_df.sort_values(
    by="Accuracy",
    ascending = False
)
result_df
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC AUC
# 2        Decision Tree    1.0000   1.000000  1.000000  1.000000  1.000000
# 3        Random Forest    1.0000   1.000000  1.000000  1.000000  1.000000
# 5              XGBoost    1.0000   1.000000  1.000000  1.000000  1.000000
# 0  Logistic Regression    0.8510   0.727047  0.609148  0.662896  0.912976
# 4                  SVM    0.7595   0.000000  0.000000  0.000000  0.500000
# 6          Naive Bayes    0.7595   0.000000  0.000000  0.000000  0.742367
# 1                  KNN    0.7035   0.233333  0.101871  0.141823  0.497403
