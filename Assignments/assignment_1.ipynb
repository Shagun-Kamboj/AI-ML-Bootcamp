# %%
section 2
# concept recall question
1) what is the difference between == and is in python?give one example where they produce different resuts.
    # my answer:- == compare value which is equal or not whereas is check a substring is present into a string or not
                  example str1="english"
                          str2="englsh"
                          str1==str2(both value is same so this return true)
                          str2 is str1(it return true)
    #reason :- == compare character by character
                is find the substring into a string
    # correct answer:- == checks for value equality whereas is check for object identy
                        list a=[1,2,3]
                        list b=[1,2,3]
                        list a==list b(return true)
                        list a is list b(return false)
    # correct reason:- it return true the content is same
                        it return false because both is stored in different location

# %%
 str1="english"
 str2="english"
 str1==str2
# Out:
# True

# %%
str1="english"
str2="englsh"
str1 is str2
# Out:
# False

# %%
lista=[1,2,3]
listb=[1,2,3]
print(lista==listb)
print(lista is listb)
# Out:
# True
# False

# %%
2)why does 0.1+0.2==0.3 returm false? what is the correct way to compare floats?
# my answer:- because computer store floating point number in binary form.the correct way to compare is to use math.isclose()
#reason :- because floating point number have small precision error

# %%
import math
math.isclose(0.1+0.2,0.3)
# Out:
# True

# %%
3) Explain the LEGB rule. in what order does python resolove a variable name?
# my answer:- The python LEGB rue is that searches a variable name in four different scopes local,enclosing,globle,built-in.
local:- defined inside a function
enclosed:- defined inside enclosing function
globle:- defined at the uppermost level
built-in:- reserved names in python builtin modules

# %%
4) what is a mutable default argument bug? how do you fix it?
# my answer:- mutable default argument bug occur when we convert mutable things into default arguments as like list[],dictionary{} etc.the way to fix it set the default argument to none.
#reason :- we use none as a default argument to avoid sharing mutable object

# %%
5) What does and return when all values are truthy? What does or return when all values are falsy?
# my answer:- AND return true when all values are true.OR return false when all values are false

# %%
6) What is the difference between // and /? What does -7 // 2 return and why?
# my answer:- // gives floor division whereas / give true division.it return -4
#reason :- -7//2 ->-3.5 but // gives floor division so so it return -4

# %%
7) What does for-else do in Python? When does the else block run?
# my answer:- for else is a loop construct in python.else block runs when for loop execute completly without break statement.

# %%
8) Why should you never use str += inside a loop? What should you use instead?
# my answer:- string is immutable it create new object at every time.if we use this then memory is wasted.we use join() instead of str+=.
#reason :- join() combine all string in one operation for making faster

# %%
9) What is the difference between a generator and a list comprehension?
# my answer:- generator calculate the item and store at a time whereas list comparision calculate and store all item in memory at once.

# %%
10) What does @functools.wraps(func) do, and why is it mandatory in decorators?
# my answer:-functool is a python module wraps is a decorators that is use in wrapper function.it is mandatory because without this we loss the metadata
so to preserve the metadata we use @functools.wraps(func) in decorators.

# %%
# rapid-fire questons:-
1. What does type(True) return? 
# my answer:- nameerror.type is a fuction which return type
# reason:- because if we write "true" then return str

# %%
2. Is bool a subclass of int in Python?
# my answer:- yes,bool a subclass of int in Python
# reason:- because in bool two value is there true(1),false(0)
# Out:
# str

# %%
3. What is the output of True + True + True 
# my answer:- output is 3
#reason:- because true=1 so 1+1+1=3
# Out:
# 3

# %%
4. What Python version introduced the walrus operator :=?
# my answer:- walrus operator is introduced in python 3.8

# %%
5. What Python version introduced match-case?
# my answer:- match-case is introduced in python 3.10

# %%
6. What is the CPython integer cache range? 
# my answer:-CPython is a small integer which range is -5 to 256

# %%
7. What does id() return?
# my answer:- id() return the memory address where it is store

# %%
8. Name three falsy values in Python.
# my answer:- 0,none,[](empty list)

# %%
9. What operator checks membership in a collection?
# my answer:- in and not in checks membership in a collection

# %%
10. What does **kwargs capture in a function?
# my answer:-**kwargs capture arbitary number of argument

# %%
 Fill in the Blanks:-
# 1. To compare floats correctly:
     abs(a - b) < tolerance_______
# Out:
# 2082006741808

# %%
# 2. To swap two variables in one line:
a, b = b,a

# %%
# 3. To check if a variable is None (idiomatic way):
if result ___is_____ None:

# %%
# 4. The correct fix for mutable default argument:
def append_item(item, lst=None):
  if lst is None:
     lst = []

# %%
# 5. To build a string from a list efficiently:
words=["a","b","c"]
result = "".join(words)
print(result)
# Out:
# abc

# %%
# 6. The walrus operator in a while loop:
while chunk := f.read(1024):
   process(chunk)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # 6. The walrus operator in a while loop:
# ----> 2 while chunk := f.read(1024):
#       3    process(chunk)
#
# NameError: name 'f' is not defined

# %%
# 7. To preserve function metadata in a decorator:
@functools.____wraps____(func)
def wrapper(*args, **kwargs):

# %%
# 8. Floor division of -9 by 2 equals: -5

# %%
# 9. To get both index and value in a loop:
for i, v in _enumerate_(my_list)

# %%
# 10. 'and' returns the _false one value and both value is__ falsy value, or the ___return true_____ value if all truthy

# %%
#secton 3
easy level:-

# %%
# E1 — Your prediction: ___________
x = 10
y = 3
print(x // y)  # my answer:- 3    #reason:- because this is floor division it gives smaller value of actual result
print(x % y)   # my answer:- 1    #reason:- because this is modules it return the reminder
print(x / y)   # my answer:- 3.3  #reason:- because it is true division it return the actual value

# %%
# E2 — Your prediction: ___________
name = "  Alice  "
print(name.strip().upper().replace('A', '@'))
# my answer:- @LICE
#reason:- strip() remove the extra space,upper() convert all character in upper case,replace() exchange A into @

# %%
# E3 — Your prediction: ___________
a = [1, 2, 3]
b = a
b.append(4)
print(a)
# my answer:- [1,2,3,4]
#reason:-append is a function which add the value at the end of the list
print(a is b)    # my answer:- true   #reason:- because all the number in a is present in b

# %%
# E4 — Your prediction: ___________
print(bool(""), bool(" "), bool(0), bool([0]), bool(None))
# my answer:- false,true,false,true,false
#reason:- "" is a empty so in python we consider false," " in this a space is present so in python we consider true,0 consider false in python,
[0] this is a non empty list so in python we consider true,None is a false statement in python

# %%
 Intermediate Level
# I1 — Your prediction: ___________
print(0 and "hello")
# my answer:- 0
#reason:-0 is false in python and hello is a non empty string so it consider true.AND is true if both the input is true
print("" or "default") 
# my answer:- default
#reason:- "" is false because it is empty string and default is a non empty string it is true OR gives true if one and both input is true
print(None or [] or 0) 
# my answer:- false
#reason:- none is false,[] is false, 0 is false so output is false because OR return true if one and both the input is true
print("a" and "b" and "c")
# my answer:- c
#reason:- all are non empty string so first a(true) and b(true) so output is b then b(true) and c(true) so final output is c

# %%
# I2 — Your prediction: ___________
x = 5
result = "positive" if x > 0 else "negative" if x < 0 else "zero"
print(result)
y = -3
result2 = "positive" if y > 0 else "negative" if y < 0 else "zero"
print(result2)
# my answer:- "positive","negative"
#reason:- because x>0 so it return positive, because y<o so it return negative

# %%
# I3 — Your prediction: ___________
s = "Hello, World!"
print(s[7:12])   # my answer:- world
print(s[::-1])   # my answer:- !dlroW ,olleH
print(s[::2])    # my answer:- Hlo ol!

# %%
# I4 — Your prediction: ___________
def f(x, multiplier=2):
    return x * multiplier
print(f(3))                  # my answer:- 6    #reason:- 3*2=6
print(f(3, 3))               # my answer:- 9    #reason:- 3*3=9
print(f(multiplier=5, x=4))  # my answer:- 20   #reason:-4*5=20

# %%
# T1 — Your prediction: ___________
print(-7 // 2)   # my answer:- -4
print(-7 % 2)    # my answer:- 1         #reason:- a%b = a-(b*(a//b))  ->-7-(2*-4)=-7+8=1
print(7 // -2)   # my answer:- -4
print(7 % -2)    # my answer:- -1        #reason:- 7-(-2*(7//-2))=7-8=-1

# %%
# T2 — Your prediction: ___________
print(2 ** 3 ** 2)      # my answer:- 512
print((2 ** 3) ** 2)    # my answer:-64

# %%
# T3 — Your prediction: ___________
def add_tag(item, tags=[]):
    tags.append(item)
    return tags
print(add_tag("python"))      # my answer:- ["python"]
print(add_tag("ml"))          # my answer:- ["python","ml"]
print(add_tag("ai"))          # my answer:- ["python","ml","ai"]

# %%
# T4 — Your prediction: ___________
funcs = []
for i in range(3):
    funcs.append(lambda: i)
print([f() for f in funcs])
 # my answer:- [1,2,3]

# %%
 Hidden Behavior Questions
# H1 — Integer caching: Your prediction: ___________
a = 256
b = 256
print(a is b)       # my answer:- true  #reason:- cache range is -5 to 256 so a and b point to same object
c = 257
d = 257
print(c is d)        # my answer:-false  #reason:- c create a new object and d also create a new object because it is out of range

# %%
# H2 — Boolean arithmetic: Your prediction: ___________
print(True + True)                              # my answer:- 2           #reason:-1+1=2
print(True * 10)                                # my answer:- 10          #reason:- 1*10=10
print(sum([True, False, True, True, False]))    # my answer:- 3           #reason:-sum[1,0,1,1,0]=3
print(int(True), int(False))                    # my answer:- 1 0         #reason:- true =1,false =0

# %%
# H3 — for-else: Your prediction: ___________
for n in [2, 4, 6, 8]:
if n % 2 != 0:
print("Found odd")
break
else:
print("All even")
# my answer:- "all even"
for n in [2, 3, 6, 8]:
if n % 2 != 0:
print("Found odd")
break
else:
print("All even")
# my answer:- "found odd"

# %%
# section 4
#def greet(name)
 #   message = f"Hello, {name}!"
  #  return message
def greet(name):
    message = f"Hello, {name}!"
    return message
# my answer:- syntax error
#reason:- outside the function parentheses and colon is missing

# %%
# SYN-2: This code has 2 syntax errors
#for i in range(5)
  #  if i % 2 = 0:
   #     print(i, "is even")
# SYN-2: This code has 2 syntax errors
for i in range(5):
    if (i % 2) == 0:
        print(i, "is even")
# identify bug:- two syntax error
# 1 bug first is colon
# 2 bug :-use == instead of =
# Out:
# 0 is even
# 2 is even
# 4 is even

# %%
 #Logical Errors
# LOG-1: Fee calculator (classic production bug)
# Intent: 2% fee, minimum ₹5, maximum ₹200
#def calculate_fee(amount):
 #   fee = amount * 2 / 100
  #  if fee < 5:
   #     fee == 5       # BUG: What is wrong here?
    #if fee > 200:
     #   fee == 200     # BUG: And here?
    #return fee
#print(calculate_fee(100))    # Expected: 5 (minimum applies)
#print(calculate_fee(5000))   # Expected: 100
#print(calculate_fee(15000))  # Expected: 200 (maximum applies)
def calculate_fee(amount):
    fee = amount * 2 / 100
    if fee < 5:
        fee = 5       
    if fee > 200:
        fee = 200     
    return fee
print(calculate_fee(100))    
print(calculate_fee(5000))   
print(calculate_fee(15000))
# error :- logical error
#bug 1:-use = instead of ==
#bug 2:- use = instead of ==
# Out:
# 5
# 100.0
# 200

# %%
# LOG-2: Grade classifier — why does it always print "F"?
#def classify_grade(score):
 #   if score >= 90:
  #      grade = "A"
   # elif score >= 80:
    #    grade = "B"
    #elif score >= 70:
     #   grade = "C"
    #elif score >= 60:
     #   grade = "D"
    #grade = "F"           # BUG: Where is the error?
    #return grade
#print(classify_grade(95))  # Should be A
#print(classify_grade(75))  # Should be C
#print(classify_grade(45))  # Should be F
# LOG-2: Grade classifier — why does it always print "F"?
def classify_grade(score):
    if score >= 90:
        grade = "A"
    elif score >= 80:
        grade = "B"
    elif score >= 70:
        grade = "C"
    elif score >= 60:
        grade = "D"
    else:
       grade = "F"           # BUG: Where is the error?
    return grade
print(classify_grade(95))  # Should be A
print(classify_grade(75))  # Should be C
print(classify_grade(45))  # Should be F
#explaination:- in thsi is a logical error which is else:
# Out:
# A
# C
# F

# %%
# LOG-3: Count vowels function — returns wrong count
#def count_vowels(text):
 #   count = 0
  #  for char in text:
   #     if char in "aeiou":   # BUG: What's missing?
    #        count += 1
    #return count
#print(count_vowels("Hello World"))   # Expected: 3
#print(count_vowels("APPLE"))         # Expected: 2
# LOG-3: Count vowels function — returns wrong count
def count_vowels(text):
    count = 0
    for char in text:
        if char in "aeiouAE":   # BUG: What's missing?
            count += 1
    return count
print(count_vowels("Hello World"))   # Expected: 3
print(count_vowels("APPLE"))         # Expected: 2
# explaination:- in ths code we add AE because a and A is different things not same
# Out:
# 3
# 2

# %%
# RT-1: What error does this raise? Fix it.
#def divide(a, b):
#    return a / b
#results = [divide(10, x) for x in [2, 5, 0, 1]
#Runtime Errors
# RT-1: What error does this raise? Fix it.
def divide(a, b):
    if b==0:
        return None
    return a / b
results = [divide(10, x) for x in [2, 5, 0, 1]]
print(results)
#error:- zerodivision error
# how to solve:- we use if condition to sove it
# Out:
# [5.0, 2.0, None, 10.0]

# %%
# RT-2: What error does this raise? Fix it.
#data = {"name": "Alice", "age": 25}
#print(f"Name: {data['name']}, Score: {data['score']}")
# Error type:
# Your fix (use .get() with a default)# RT-2: What error does this raise? Fix it.
data = {"name": "Alice", "age": 25}
score_value=data.get('score',0)
print(f"Name: {data['name']},Score: {'score_value'}")

# Error type: keyerror
# Out:
# Name: Alice,Score: score_value

# %%
# RT-3: UnboundLocalError — explain why and fix it
# first way
counter = 0
def increment():
    global counter
    counter += 1    # BUG: Why does this fail?
    return counter
increment()
# Explanation:tells to python to use the outsude counter
# Out:
# 1

# %%
# HIDDEN-1: This runs without error but produces WRONG results
# Intent: Remove all negative numbers from the list
numbers = [1, -2, 3, -4, 5, -6, 7]
for num in numbers[:]:
    if num < 0:
        numbers.remove(num)
print(numbers)  # What do you get? What should you get?

# in this code indx0=1,indx1=-2,then run remove(num) so the entire list is small and then index 0=1,index 1=3 but loop run for index 2 which is for -4
so 3 is skip in the iteration so we use [:] this create the temporary copy of list
# Out:
# [1, 3, 5, 7]

# %%
# HIDDEN-2: Closure late-binding bug
# Intent: Create 3 functions that return 0, 1, 2 respectively
multipliers = []
for i in range(3):
    multipliers.append(lambda x,i=i: x * i)
print([f(10) for f in multipliers])  # Expected: [0, 10, 20]. Actual?
# Out:
# [0, 10, 20]

# %%
#SECTION 05
#Edge Cases & Hidden Scenario
# EC-1: EMPTY INPUT CASES
# The function below works for normal input — make it handle all edge cases
def average(numbers):
    """Return the average of a list of numbers."""
    return sum(numbers) / len(numbers)
# Test cases to handle:
# average([])              → should return None or raise a clear ValueError
# average([5])             → should return 5.0
# average(None)            → should raise TypeError with clear message
# average(["a", "b"])      → should raise TypeError
# average([1, 2, None, 4]) → handle None in list

# %%
def average(numbers):
    """Return the average of a list of numbers."""
    if len(numbers)==0:
        return None
    return sum(numbers) / len(numbers)
print(average([]) )
# Out:
# None

# %%
def average(numbers):
    """Return the average of a list of numbers."""
    return sum(numbers) / len(numbers)
print(average([5]))
# Out:
# 5.0

# %%
def average(numbers):
    """Return the average of a list of numbers."""
    if numbers is None:
        raise TypeError("input cannot be none")
    return sum(numbers) / len(numbers)
print(average(None))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       4         raise TypeError("input cannot be none")
#       5     return sum(numbers) / len(numbers)
# ----> 6 print(average(None))
#
# Cell In[10], line 4, in average(numbers)
#       2 """Return the average of a list of numbers."""
#       3 if numbers is None:
# ----> 4     raise TypeError("input cannot be none")
#       5 return sum(numbers) / len(numbers)
#
# TypeError: input cannot be none

# %%
def average(numbers):
    """Return the average of a list of numbers."""
    for num in numbers:
        if not isinstance(num,(int,float)):
            raise TypeError("all element in the list must be integer and floats")
    return sum(numbers) / len(numbers)
average(["a", "b"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 7
#       5             raise TypeError("all element in the list must be integer and floats")
#       6     return sum(numbers) / len(numbers)
# ----> 7 average(["a", "b"])
#
# Cell In[13], line 5, in average(numbers)
#       3 for num in numbers:
#       4     if not isinstance(num,(int,float)):
# ----> 5         raise TypeError("all element in the list must be integer and floats")
#       6 return sum(numbers) / len(numbers)
#
# TypeError: all element in the list must be integer and floats

# %%
def average(numbers):
    new_list=[]
    for num in numbers:
        if num is not None:
            new_list.append(num)
    """Return the average of a list of numbers."""
    return sum(new_list) / len(new_list)
average([1, 2, None, 4])
# Out:
# 2.3333333333333335

# %%
# EC-2: BOUNDARY CONDITIONS
# Check if a password meets requirements:
# Length: 8-20 chars, has uppercase, lowercase, digit, special char
def is_valid_password(pwd):
    # Test these boundaries:
    # ""           → False (empty)
    # "abc"        → False (too short)
    # "a" * 21     → False (too long)
    # "Abcdefg1!"  → True
    # "ABCDEFG1!"  → False (no lowercase)
    # "abcdefg1!"  → False (no uppercase)
    # "Abcdefgh!"  → False (no digit)
    # "Abcdefg12"  → False (no special char)
    pass

# %%
def is_valid_password(pwd):
    if len(pwd)<8 or len(pwd)>20:
        return False
    return true
print(is_valid_password(""))
# Out:
# False

# %%
def is_valid_password(pwd):
    if len(pwd)<8 or len(pwd)>20:
        return False
    return true
print(is_valid_password("abc"))
# Out:
# False

# %%
def is_valid_password(pwd):
    if len(pwd)<8 or len(pwd)>20:
        return False
    return true
print(is_valid_password("a"*21))
# Out:
# False

# %%
def is_valid_password(pwd):
    in_lowercase=any(char.islower() for char in pwd)
    if not in_lowercase:
        return False
    return True
print(is_valid_password("ABCDEFG1!"))
# Out:
# False

# %%
def is_valid_password(pwd):
    in_uppercase=any(char.isupper() for char in pwd)
    if not in_uppercase:
        return False
    return True
print(is_valid_password("abcefg1!"))
# Out:
# False

# %%
def is_valid_password(pwd):
    in_digit=any(char.isdigit() for char in pwd)
    if not in_digit:
        return False
    return True
print(is_valid_password("Abcdfgh!"))
# Out:
# False

# %%
def is_valid_password(pwd):
    return any(not char.isalnum() for char in pwd)
print(is_valid_password("Abcdefg12"))
# Out:
# False

# %%
# EC-3: INVALID INPUT CASES
# A student age validator for a school system:
def validate_student_age(age):
    """Return True if age is valid for school (5-18)."""
    return 5 <= age <= 18
# Make this robust against:
# validate_student_age("fifteen")   → TypeError
# validate_student_age(-1)          → False
# validate_student_age(None)        → TypeError
# validate_student_age(15.7)        → handle float (round or reject?)
# validate_student_age("15")        → handle string number (convert or reject?)

# %%
def validate_student_age(age):
    """Return True if age is valid for school (5-18)."""
    if isinstance(age,str) and not age.isdigit():
        raise TypeError("age is in the form of number")
    return 5 <= age <= 18
validate_student_age("fifteen")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 6
#       4         raise TypeError("age is in the form of number")
#       5     return 5 <= age <= 18
# ----> 6 validate_student_age("fifteen")
#
# Cell In[43], line 4, in validate_student_age(age)
#       2 """Return True if age is valid for school (5-18)."""
#       3 if isinstance(age,str) and not age.isdigit():
# ----> 4     raise TypeError("age is in the form of number")
#       5 return 5 <= age <= 18
#
# TypeError: age is in the form of number

# %%
def validate_student_age(age):
    """Return True if age is valid for school (5-18)."""
    if age<0:
        return False
    return 5 <= age <= 18
validate_student_age(-1)
# Out:
# False

# %%
def validate_student_age(age):
    """Return True if age is valid for school (5-18)."""
    if age is None:
        raise TypeError("age can't be None")
    return 5 <= age <= 18
validate_student_age(None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 6
#       4         raise TypeError("age can't be None")
#       5     return 5 <= age <= 18
# ----> 6 validate_student_age(None)
#
# Cell In[46], line 4, in validate_student_age(age)
#       2 """Return True if age is valid for school (5-18)."""
#       3 if age is None:
# ----> 4     raise TypeError("age can't be None")
#       5 return 5 <= age <= 18
#
# TypeError: age can't be None

# %%
def validate_student_age(age):
    """Return True if age is valid for school (5-18)."""
    if isinstance(age,float):
        return False
    return 5 <= age <= 18
validate_student_age(15.7)
# Out:
# False

# %%
def validate_student_age(age):
    """Return True if age is valid for school (5-18)."""
    if isinstance(age,str) and age.isdigit():
        age=int(age)
    if isinstance(age,int):
        return False
    return 5 <= age <= 18
validate_student_age("15")
# Out:
# False

# %%
# EC-4: LARGE DATA SCENARIO
# The code below works for small lists. What happens at scale? Rewrite it.
# Original (inefficient):
def find_duplicates_slow(items):
    """Find items that appear more than once."""
    duplicates = []
    for i in range(len(items)):
        for j in range(i + 1, len(items)):
            if items[i] == items[j] and items[i] not in duplicates:
                duplicates.append(items[i])
    return duplicates
# Questions:
# 1. What is the time complexity of this function? O(___)
# 2. What is the space complexity? O(___)
# 3. At 1 million items, roughly how many comparisons? ___
# 4. Rewrite it with O(n) time using a set/dict:

# %%
SECTION 07 Think Like an Engineer

# %%
Scenario A: A function 
get_user_data(user_id) fetches a user's data from a database and returns a dict.
1. What could go wrong? List at least 5 failure modes.
    # answer:- Database Down
               network timeout
               user not found
               data format Error
2. What assumptions is the current design making?
# answer:- database is always available
data connectivity is stable
user record exists
3. How would you validate inputs before the DB call?
# answer:- type checking
length check
4. How would this behave at scale? (1 million calls/hour)
# answer:- at 1 million calls/hour database experience heavy losd,causing slower response time and possible timeout.
5. What business impact could failures cause?
# answer:- failure can prevent user from accessing their data

# %%
Scenario B: A loop processes 10,000 order records. For each order, it builds a report string using += .
1. What is the time complexity of string += in a loop? Why?
# answer:-the time complexity of string += in a loop is O(n2)beacuse string is immutable
2. How much memory could this consume for 10,000 records of 1KB each?
# answer:-the final report is about 10 MB
3. What is the correct approach?
# answer:- store string in a list and use "".join(list) at the end
4. How would you test that your fix actually improved performance?
# answer:- measure execution time and memory usuage of both versoins

# %%
Scenario C: A discount function uses 
if coupon == "SAVE10" or coupon == "SAVE20" or coupon == 
"FLAT50": .
1. What is wrong with this approach as the number of coupons grows?
# answer:-code become very lond and difficult to manage
2. How would you redesign it for maintainability?
# answer:-
3. What happens when a new coupon type is added? Who else's code might break?
# answer:-

# %%
##SECTION 08
 #Hands-On Coding Practice
# ── BEGINNER ─────────────────────────────────────────────────────────────────
# B1: Write a function that takes a temperature in Celsius and returns it in
# Fahrenheit AND Kelvin. Return as a tuple: (fahrenheit, kelvin)
# Formula: F = (C × 9/5) + 32 | K = C + 273.15
def convert_temperature(celsius):
    fahrenhetit =(celsius*9/5)+32
    kelvin=celsius+273.15
    return(fahrenhetit,kelvin)
# Tests:
assert convert_temperature(0) == (32.0, 273.15)
assert convert_temperature(100) == (212.0, 373.15)
print("B1 passed ")
# Out:
# B1 passed

# %%
# B2: Write a function that checks if a string is a palindrome
# Ignore case and spaces
# "A man a plan a canal Panama" → True
# "hello" → False
def is_palindrome(text):
    cleaned_text =text.lower().replace(" ","")
    return cleaned_text==cleaned_text[::-1]
# Tests:
assert is_palindrome("racecar") == True
assert is_palindrome("hello") == False
assert is_palindrome("A man a plan a canal Panama") == True
assert is_palindrome("") == True
print("B2 passed ")
# Out:
# B2 passed

# %%
# B3: FizzBuzz (classic — but do it in ONE comprehension, not a loop)
# For numbers 1-30: "Fizz" if divisible by 3, "Buzz" if by 5,
# "FizzBuzz" if both, else the number itself
fizzbuzz = [
    "FizzBuzz" if i % 15 == 0
    else "Fizz" if i % 3 == 0
    else "Buzz" if i % 5 == 0
    else i
    for i in range(1, 31)
]

# Test:
assert fizzbuzz[2] == "Fizz"       # 3
assert fizzbuzz[4] == "Buzz"       # 5
assert fizzbuzz[14] == "FizzBuzz"  # 15
assert fizzbuzz[6] == 7

print("B3 passed ", fizzbuzz[:15])
# Out:
# B3 passed  [1, 2, 'Fizz', 4, 'Buzz', 'Fizz', 7, 8, 'Fizz', 'Buzz', 11, 'Fizz', 13, 14, 'FizzBuzz']
